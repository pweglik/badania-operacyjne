# %%
import pandas as pd

gs = pd.read_csv("gridsearch3.csv")

# %%
gs.head()
# Out:
#    survival_functions  epochs  chance_rot_cycle  chance_rot_right  \
# 0                   1     100               0.5               0.5
# 1                   1     100               0.5               0.5
# 2                   1     100               0.5               0.5
# 3                   1     100               0.5               0.5
# 4                   1     100               0.5               0.5
#
#    chance_invert  chance_erase_stop  chance_add_stop  chance_add_stop_mix  \
# 0            0.5                0.2              0.2                  0.2
# 1            0.5                0.2              0.2                  0.2
# 2            0.5                0.2              0.2                  0.2
# 3            0.5                0.2              0.2                  0.2
# 4            0.5                0.2              0.2                  0.2
#
#    chance_replace_stops  chance_replace_stops_proximity  ...  chance_cycle  \
# 0                   0.2                             0.2  ...           0.1
# 1                   0.2                             0.2  ...           0.1
# 2                   0.2                             0.2  ...           0.1
# 3                   0.2                             0.2  ...           0.1
# 4                   0.2                             0.2  ...           0.1
#
#    chance_erase_line  chance_merge  chance_merge_mix  chance_split  \
# 0               0.25          0.25               0.2          0.75
# 1               0.25          0.25               0.2          0.75
# 2               0.25          0.25               0.2          0.75
# 3               0.25          0.25               0.2          0.75
# 4               0.25          0.25               0.2          0.75
#
#    cycle_stops_shift  chance_merge_specimen  chance_cycle_stops_shift  \
# 0                0.8                    0.5                       0.2
# 1                0.2                    0.5                       0.2
# 2                0.8                    0.5                       0.2
# 3                0.8                    0.5                       0.8
# 4                0.2                    0.5                       0.8
#
#    chance_line_based_merge    fitness
# 0                      0.2  34.265141
# 1                      0.2  34.717461
# 2                      0.8  32.315981
# 3                      0.2  33.713768
# 4                      0.2  33.603771
#
# [5 rows x 21 columns]

# %%
# keys = [
#     "survival_functions",
#     "chance_create_line",
#     "chance_cycle",
#     "chance_erase_line",
#     "chance_invert",
#     "chance_merge",
#     "chance_merge_specimen",
#     "chance_rot_cycle",
#     "chance_rot_right",
#     "chance_split",
# ]

keys = [
    "survival_functions",
    "chance_erase_stop",
    "chance_add_stop",
    "chance_add_stop_mix",
    "chance_replace_stops",
    "chance_replace_stops_proximity",
    "chance_merge_mix",
    "cycle_stops_shift",
    "chance_cycle_stops_shift",
    "chance_line_based_merge",
]

# %%
import numpy as np
import matplotlib.pyplot as plt

for i, key in enumerate(keys):
    values = gs[key].unique()
    for val in values:
        fitness = gs[gs[key] == val]["fitness"]
        hist, bins = np.histogram(fitness, bins=30)
        plt.hist(fitness, bins=bins, label=f"{key}={val}", alpha=0.5, rwidth=1)

    plt.xlabel("funkcja dopasowania")
    plt.ylabel("liczba testów")
    plt.title(f"dopasowanie względem {key}")
    plt.legend()
    plt.savefig(f"{i+1}.png")
    plt.show()
